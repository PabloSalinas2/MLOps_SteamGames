# %% [markdown]
# ##### ***1) LECTURA DE ARCHIVOS***

# %%
import pandas as pd
import gzip
import json
import ast

path_items='../PROYECTO INDIVIDUAL/Datos del Proyecto/users_items.json/australian_users_items.json'

# %%
items_list=[]
no_leidos=[]
with open(path_items,'r',encoding='utf-8') as archivo:
    for nro_fila,fila in enumerate(archivo,start=1):
        try:
            datos=ast.literal_eval(fila)
            if isinstance(datos,dict):
                items_list.append(datos)
            else:
                no_leidos.append[nro_fila]
        except json.JSONDecodeError as e:
            no_leidos.append(nro_fila)

# %% [markdown]
# ##### ***2) CONSTRUCCION DE ETL***

# %%
# DESANIDAR COLUMNA "items"

lista_desanidada_items=[]
for indice,diccionario in enumerate(items_list):
    for inidex,diccionario_sec in enumerate(diccionario['items']):
        lista_desanidada_items.append({'user_id':diccionario['user_id'],
                        'items_count':diccionario['items_count'],
                        'steam_id':diccionario['steam_id'],
                        'user_url':diccionario['user_url'],
                        'item_id':diccionario_sec['item_id'],
                        'item_name':diccionario_sec['item_name'],
                        'playtime_forever':diccionario_sec['playtime_forever'],
                        'playtime_2weeks':diccionario_sec['playtime_2weeks']
                        })

users_items=pd.DataFrame(lista_desanidada_items)

# %%
users_items
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5153204  76561198329548331            7  76561198329548331
# 5153205  76561198329548331            7  76561198329548331
# 5153206  76561198329548331            7  76561198329548331
# 5153207  76561198329548331            7  76561198329548331
# 5153208  76561198329548331            7  76561198329548331
#
#                                                   user_url item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10
# 1        http://steamcommunity.com/profiles/76561197970...      20
# ...

# %%
# ELIMIACION de columnas innecesarias 

users_items.drop(['user_url'],axis=1,inplace=True)

# %%
users_items.drop(['steam_id'],axis=1,inplace=True)

# %%
users_items.drop(['items_count'],axis=1,inplace=True)

# %%
users_items
# Out:
#                    user_id item_id                      item_name  \
# 0        76561197970982479      10                 Counter-Strike
# 1        76561197970982479      20          Team Fortress Classic
# 2        76561197970982479      30                  Day of Defeat
# 3        76561197970982479      40             Deathmatch Classic
# 4        76561197970982479      50      Half-Life: Opposing Force
# ...                    ...     ...                            ...
# 5153204  76561198329548331  346330                   BrainBread 2
# 5153205  76561198329548331  373330                    All Is Dust
# 5153206  76561198329548331  388490  One Way To Die: Steam Edition
# 5153207  76561198329548331  521570          You Have 10 Seconds 2
# 5153208  76561198329548331  519140                     Minds Eyes
#
#          playtime_forever  playtime_2weeks
# 0                       6                0
# 1                       0                0
# ...

# %%
# renombrar columnas para mejor identificacion 

users_items=users_items.rename(columns={'item_id':'id_juego','item_name':'nombre_juego','playtime_forever':'timpo_total_jugado','playtime_2weeks':'tiempo_jugado_ultimas_2semanas'})

# %%
# Ver si hay valores nulos 

for columna in users_items.columns:

    nulo=users_items[columna].isnull().sum()
    print(f'{columna} valores nulos= ',nulo)
# Out:
# user_id valores nulos=  0
# id_juego valores nulos=  0
# nombre_juego valores nulos=  0
# timpo_total_jugado valores nulos=  0
# tiempo_jugado_ultimas_2semanas valores nulos=  0

# %%
users_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5153209 entries, 0 to 5153208
# Data columns (total 5 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   user_id                         object
#  1   id_juego                        object
#  2   nombre_juego                    object
#  3   timpo_total_jugado              int64
#  4   tiempo_jugado_ultimas_2semanas  int64
# dtypes: int64(2), object(3)
# memory usage: 196.6+ MB

# %%
users_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5153209 entries, 0 to 5153208
# Data columns (total 5 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   user_id                         object
#  1   id_juego                        int32
#  2   nombre_juego                    object
#  3   timpo_total_jugado              int64
#  4   tiempo_jugado_ultimas_2semanas  int64
# dtypes: int32(1), int64(2), object(2)
# memory usage: 176.9+ MB

# %%
# Cambiar tipo de la columna "id_juego"
users_items['id_juego']=users_items['id_juego'].astype(int)

# %%
# Data frame user_items listo

users_items
# Out:
#                    user_id  id_juego                   nombre_juego  \
# 0        76561197970982479        10                 Counter-Strike
# 1        76561197970982479        20          Team Fortress Classic
# 2        76561197970982479        30                  Day of Defeat
# 3        76561197970982479        40             Deathmatch Classic
# 4        76561197970982479        50      Half-Life: Opposing Force
# ...                    ...       ...                            ...
# 5153204  76561198329548331    346330                   BrainBread 2
# 5153205  76561198329548331    373330                    All Is Dust
# 5153206  76561198329548331    388490  One Way To Die: Steam Edition
# 5153207  76561198329548331    521570          You Have 10 Seconds 2
# 5153208  76561198329548331    519140                     Minds Eyes
#
#          timpo_total_jugado  tiempo_jugado_ultimas_2semanas
# 0                         6                               0
# ...

# %%
# EXPORTAR dataframe en formato csv 

nombre_archivo='user_items.csv'

users_items.to_csv(nombre_archivo,index=False)
